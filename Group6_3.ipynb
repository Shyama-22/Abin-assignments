# %%
pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.23.5)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.2)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from Bio import Entrez, SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Align import MultipleSeqAlignment
from collections import Counter
import time

def Q1(strain_names, common_length):
    # Set your email address for Entrez (required by NCBI)
    Entrez.email = "shivam21489@iiitd.ac.in"  # Replace with your email address

    # Create a dictionary to store sequence records
    sequence_records = {}

    for strain_name in strain_names:
        # Define your query to search for the strain
        query = f"Coronavirus {strain_name} complete genome"

        # Use Entrez to search for the sequence and retrieve the first result
        handle = Entrez.esearch(db="nucleotide", term=query, retmax=1)
        record = Entrez.read(handle)
        handle.close()

        if record['Count'] == "0":
            print(f"No results found for {strain_name}.")
        else:
            # Retrieve the sequence record using the accession number
            accession = record['IdList'][0]

            # Introduce a delay to respect NCBI's rate limits
            time.sleep(3)

            handle = Entrez.efetch(db="nucleotide", id=accession, rettype="gb", retmode="text")
            seq_record = SeqIO.read(handle, "genbank")
            handle.close()

            # Convert the sequence to a string, pad it with 'N', and then convert it back to a Seq object
            seq_str = str(seq_record.seq)
            if len(seq_str) < common_length:
                padding = 'N' * (common_length - len(seq_str))
                seq_str += padding
            seq_record.seq = Seq(seq_str)

            sequence_records[strain_name] = seq_record

            # Save the sequence to a GenBank file
            sequence_file = f"{strain_name}_sequence.gb"
            SeqIO.write(seq_record, sequence_file, "genbank")
            print(f"Downloaded {strain_name} sequence and saved it to {sequence_file}")

    # Perform MSA for all sequences
    alignment = MultipleSeqAlignment(list(sequence_records.values()))
    output_file = "coronavirus_alignment.aln"

    # Save the MSA in ClustalW format
    SeqIO.write(alignment, output_file, "clustal")

    # Calculate percent identity and identify mutations
    seq_length = len(alignment[0])
    mutations = []

    for i in range(seq_length):
        column = alignment[:, i]
        column_sequences = [Seq(seq) for seq in column]
        column_letters = [str(seq) for seq in column_sequences]
        column_counter = Counter(column_letters)

        if len(column_counter) > 1:
            # There is a mutation at this position
            mutations.append((i + 1, column_counter))

    percent_identity = 100 * (1 - len(mutations) / seq_length)

    # Print mutations and percent identity
    print(f"Mutations:")
    for position, counts in mutations:
        print(f"Position {position}: {counts}")
    print(f"Percent Identity: {percent_identity:.2f}%")

    # Comment on the pathogenesis of the mutations (if any)
    # You can add your comments based on the mutations identified.

    return percent_identity

# Example of how to use the Q1 function with sample test case arguments
sample_test_case = ["Alpha", "Beta", "Gamma"]
common_length = 30287
output = Q1(sample_test_case, common_length)
# Out:
# Streaming output truncated to the last 5000 lines.
# Position 1872: Counter({'G': 2, 'N': 1})
# Position 1873: Counter({'T': 2, 'N': 1})
# Position 1874: Counter({'A': 2, 'N': 1})
# Position 1875: Counter({'C': 2, 'N': 1})
# Position 1876: Counter({'C': 2, 'N': 1})
# Position 1877: Counter({'A': 2, 'N': 1})
# Position 1878: Counter({'A': 2, 'N': 1})
# Position 1879: Counter({'C': 2, 'N': 1})
# Position 1880: Counter({'C': 2, 'N': 1})
# Position 1881: Counter({'T': 2, 'N': 1})
# Position 1882: Counter({'C': 2, 'N': 1})
# Position 1883: Counter({'A': 2, 'N': 1})
# Position 1884: Counter({'C': 2, 'N': 1})
# Position 1885: Counter({'C': 2, 'N': 1})
# Position 1886: Counter({'A': 2, 'N': 1})
# Position 1887: Counter({'A': 2, 'N': 1})
# Position 1888: Counter({'C': 2, 'N': 1})
# Position 1889: Counter({'A': 2, 'N': 1})
# Position 1890: Counter({'T': 2, 'N': 1})
# Position 1891: Counter({'T': 2, 'N': 1})
# Position 1892: Counter({'A': 2, 'N': 1})
# Position 1893: Counter({'C': 2, 'N': 1})
# Position 1894: Counter({'A': 2, 'N': 1})
# Position 1895: Counter({'G': 2, 'N': 1})
# Position 1896: Counter({'A': 2, 'N': 1})
# Position 1897: Counter({'G': 2, 'N': 1})
# Position 1898: Counter({'G': 2, 'N': 1})
# Position 1899: Counter({'C': 2, 'N': 1})
# Position 1900: Counter({'C': 2, 'N': 1})
# Position 1901: Counter({'T': 2, 'N': 1})
# Position 1902: Counter({'A': 2, 'N': 1})
# Position 1903: Counter({'C': 2, 'N': 1})
# Position 1904: Counter({'T': 2, 'N': 1})
# Position 1905: Counter({'C': 2, 'N': 1})
# Position 1906: Counter({'A': 2, 'N': 1})
# Position 1907: Counter({'T': 2, 'N': 1})
# Position 1908: Counter({'A': 2, 'N': 1})
# Position 1909: Counter({'T': 2, 'N': 1})
# Position 1910: Counter({'G': 2, 'N': 1})
# Position 1911: Counter({'A': 2, 'N': 1})
# Position 1912: Counter({'A': 2, 'N': 1})
# Position 1913: Counter({'C': 2, 'N': 1})
# Position 1914: Counter({'C': 2, 'N': 1})
# Position 1915: Counter({'A': 2, 'N': 1})
# Position 1916: Counter({'A': 2, 'N': 1})
# Position 1917: Counter({'A': 2, 'N': 1})
# Position 1918: Counter({'T': 2, 'N': 1})
# Position 1919: Counter({'G': 2, 'N': 1})
# Position 1920: Counter({'G': 2, 'N': 1})
# Position 1921: Counter({'T': 2, 'N': 1})
# Position 1922: Counter({'G': 2, 'N': 1})
# Position 1923: Counter({'T': 2, 'N': 1})
# Position 1924: Counter({'T': 2, 'N': 1})
# Position 1925: Counter({'T': 2, 'N': 1})
# Position 1926: Counter({'C': 2, 'N': 1})
# Position 1927: Counter({'A': 2, 'N': 1})
# Position 1928: Counter({'C': 2, 'N': 1})
# Position 1929: Counter({'A': 2, 'N': 1})
# Position 1930: Counter({'A': 2, 'N': 1})
# Position 1931: Counter({'A': 2, 'N': 1})
# Position 1932: Counter({'A': 2, 'N': 1})
# Position 1933: Counter({'T': 2, 'N': 1})
# Position 1934: Counter({'C': 2, 'N': 1})
# Position 1935: Counter({'A': 2, 'N': 1})
# Position 1936: Counter({'G': 2, 'N': 1})
# Position 1937: Counter({'A': 2, 'N': 1})
# Position 1938: Counter({'A': 2, 'N': 1})
# Position 1939: Counter({'A': 2, 'N': 1})
# Position 1940: Counter({'T': 2, 'N': 1})
# Position 1941: Counter({'G': 2, 'N': 1})
# Position 1942: Counter({'A': 2, 'N': 1})
# Position 1943: Counter({'A': 2, 'N': 1})
# Position 1944: Counter({'G': 2, 'N': 1})
# Position 1945: Counter({'A': 2, 'N': 1})
# Position 1946: Counter({'T': 2, 'N': 1})
# Position 1947: Counter({'T': 2, 'N': 1})
# Position 1948: Counter({'T': 2, 'N': 1})
# Position 1949: Counter({'G': 2, 'N': 1})
# Position 1950: Counter({'A': 2, 'N': 1})
# Position 1951: Counter({'T': 2, 'N': 1})
# Position 1952: Counter({'A': 2, 'N': 1})
# Position 1953: Counter({'T': 2, 'N': 1})
# Position 1954: Counter({'T': 2, 'N': 1})
# Position 1955: Counter({'T': 2, 'N': 1})
# Position 1956: Counter({'A': 2, 'N': 1})
# Position 1957: Counter({'A': 2, 'N': 1})
# Position 1958: Counter({'T': 2, 'N': 1})
# Position 1959: Counter({'G': 2, 'N': 1})
# Position 1960: Counter({'A': 2, 'N': 1})
# Position 1961: Counter({'A': 2, 'N': 1})
# Position 1962: Counter({'A': 2, 'N': 1})
# Position 1963: Counter({'G': 2, 'N': 1})
# Position 1964: Counter({'C': 2, 'N': 1})
# Position 1965: Counter({'C': 2, 'N': 1})
# Position 1966: Counter({'T': 2, 'N': 1})
# Position 1967: Counter({'T': 2, 'N': 1})
# Position 1968: Counter({'G': 2, 'N': 1})
# Position 1969: Counter({'G': 2, 'N': 1})
# Position 1970: Counter({'C': 2, 'N': 1})
# Position 1971: Counter({'C': 2, 'N': 1})
# Position 1972: Counter({'A': 2, 'N': 1})
# Position 1973: Counter({'A': 2, 'N': 1})
# Position 1974: Counter({'G': 2, 'N': 1})
# Position 1975: Counter({'G': 2, 'N': 1})
# Position 1976: Counter({'C': 2, 'N': 1})
# Position 1977: Counter({'A': 2, 'N': 1})
# Position 1978: Counter({'C': 2, 'N': 1})
# Position 1979: Counter({'T': 2, 'N': 1})
# Position 1980: Counter({'T': 2, 'N': 1})
# Position 1981: Counter({'T': 2, 'N': 1})
# Position 1982: Counter({'T': 2, 'N': 1})
# Position 1983: Counter({'A': 2, 'N': 1})
# Position 1984: Counter({'C': 2, 'N': 1})
# Position 1985: Counter({'A': 2, 'N': 1})
# Position 1986: Counter({'A': 2, 'N': 1})
# Position 1987: Counter({'A': 2, 'N': 1})
# Position 1988: Counter({'G': 2, 'N': 1})
# Position 1989: Counter({'A': 2, 'N': 1})
# Position 1990: Counter({'T': 2, 'N': 1})
# Position 1991: Counter({'T': 2, 'N': 1})
# Position 1992: Counter({'T': 2, 'N': 1})
# Position 1993: Counter({'T': 2, 'N': 1})
# Position 1994: Counter({'T': 2, 'N': 1})
# Position 1995: Counter({'A': 2, 'N': 1})
# Position 1996: Counter({'A': 2, 'N': 1})
# Position 1997: Counter({'A': 2, 'N': 1})
# Position 1998: Counter({'G': 2, 'N': 1})
# Position 1999: Counter({'G': 2, 'N': 1})
# Position 2000: Counter({'C': 2, 'N': 1})
# Position 2001: Counter({'G': 2, 'N': 1})
# Position 2002: Counter({'T': 2, 'N': 1})
# Position 2003: Counter({'A': 2, 'N': 1})
# Position 2004: Counter({'C': 2, 'N': 1})
# Position 2005: Counter({'G': 2, 'N': 1})
# Position 2006: Counter({'A': 2, 'N': 1})
# Position 2007: Counter({'A': 2, 'N': 1})
# Position 2008: Counter({'G': 2, 'N': 1})
# Position 2009: Counter({'A': 2, 'N': 1})
# Position 2010: Counter({'G': 2, 'N': 1})
# Position 2011: Counter({'A': 2, 'N': 1})
# Position 2012: Counter({'A': 2, 'N': 1})
# Position 2013: Counter({'G': 2, 'N': 1})
# Position 2014: Counter({'T': 2, 'N': 1})
# Position 2015: Counter({'A': 2, 'N': 1})
# Position 2016: Counter({'G': 2, 'N': 1})
# Position 2017: Counter({'G': 2, 'N': 1})
# Position 2018: Counter({'A': 2, 'N': 1})
# Position 2019: Counter({'G': 2, 'N': 1})
# Position 2020: Counter({'A': 2, 'N': 1})
# Position 2021: Counter({'C': 2, 'N': 1})
# Position 2022: Counter({'T': 2, 'N': 1})
# Position 2023: Counter({'A': 2, 'N': 1})
# Position 2024: Counter({'C': 2, 'N': 1})
# Position 2025: Counter({'G': 2, 'N': 1})
# Position 2026: Counter({'G': 2, 'N': 1})
# Position 2027: Counter({'T': 2, 'N': 1})
# Position 2028: Counter({'C': 2, 'N': 1})
# Position 2029: Counter({'A': 2, 'N': 1})
# Position 2030: Counter({'A': 2, 'N': 1})
# Position 2031: Counter({'C': 2, 'N': 1})
# Position 2032: Counter({'T': 2, 'N': 1})
# Position 2033: Counter({'G': 2, 'N': 1})
# Position 2034: Counter({'C': 2, 'N': 1})
# Position 2035: Counter({'A': 2, 'N': 1})
# Position 2036: Counter({'T': 2, 'N': 1})
# Position 2037: Counter({'G': 2, 'N': 1})
# Position 2038: Counter({'A': 2, 'N': 1})
# Position 2039: Counter({'A': 2, 'N': 1})
# Position 2040: Counter({'A': 2, 'N': 1})
# Position 2041: Counter({'C': 2, 'N': 1})
# Position 2042: Counter({'A': 2, 'N': 1})
# Position 2043: Counter({'G': 2, 'N': 1})
# Position 2044: Counter({'A': 2, 'N': 1})
# Position 2045: Counter({'A': 2, 'N': 1})
# Position 2046: Counter({'G': 2, 'N': 1})
# Position 2047: Counter({'T': 2, 'N': 1})
# Position 2048: Counter({'T': 2, 'N': 1})
# Position 2049: Counter({'C': 2, 'N': 1})
# Position 2050: Counter({'T': 2, 'N': 1})
# Position 2051: Counter({'T': 2, 'N': 1})
# Position 2052: Counter({'T': 2, 'N': 1})
# Position 2053: Counter({'T': 2, 'N': 1})
# Position 2054: Counter({'A': 2, 'N': 1})
# Position 2055: Counter({'A': 2, 'N': 1})
# Position 2056: Counter({'A': 2, 'N': 1})
# Position 2057: Counter({'A': 2, 'N': 1})
# Position 2058: Counter({'G': 2, 'N': 1})
# Position 2059: Counter({'T': 2, 'N': 1})
# Position 2060: Counter({'T': 2, 'N': 1})
# Position 2061: Counter({'C': 2, 'N': 1})
# Position 2062: Counter({'T': 2, 'N': 1})
# Position 2063: Counter({'G': 2, 'N': 1})
# Position 2064: Counter({'G': 2, 'N': 1})
# Position 2065: Counter({'A': 2, 'N': 1})
# Position 2066: Counter({'T': 2, 'N': 1})
# Position 2067: Counter({'A': 2, 'N': 1})
# Position 2068: Counter({'A': 2, 'N': 1})
# Position 2069: Counter({'A': 2, 'N': 1})
# Position 2070: Counter({'G': 2, 'N': 1})
# Position 2071: Counter({'C': 2, 'N': 1})
# Position 2072: Counter({'A': 2, 'N': 1})
# Position 2073: Counter({'C': 2, 'N': 1})
# Position 2074: Counter({'A': 2, 'N': 1})
# Position 2075: Counter({'C': 2, 'N': 1})
# Position 2076: Counter({'A': 2, 'N': 1})
# Position 2077: Counter({'G': 2, 'N': 1})
# Position 2078: Counter({'A': 2, 'N': 1})
# Position 2079: Counter({'A': 2, 'N': 1})
# Position 2080: Counter({'A': 2, 'N': 1})
# Position 2081: Counter({'C': 2, 'N': 1})
# Position 2082: Counter({'T': 2, 'N': 1})
# Position 2083: Counter({'A': 2, 'N': 1})
# Position 2084: Counter({'T': 2, 'N': 1})
# Position 2085: Counter({'T': 2, 'N': 1})
# Position 2086: Counter({'C': 2, 'N': 1})
# Position 2087: Counter({'A': 2, 'N': 1})
# Position 2088: Counter({'G': 2, 'N': 1})
# Position 2089: Counter({'A': 2, 'N': 1})
# Position 2090: Counter({'G': 2, 'N': 1})
# Position 2091: Counter({'T': 2, 'N': 1})
# Position 2092: Counter({'C': 2, 'N': 1})
# Position 2093: Counter({'T': 2, 'N': 1})
# Position 2094: Counter({'T': 2, 'N': 1})
# Position 2095: Counter({'T': 2, 'N': 1})
# Position 2096: Counter({'C': 2, 'N': 1})
# Position 2097: Counter({'T': 2, 'N': 1})
# Position 2098: Counter({'T': 2, 'N': 1})
# Position 2099: Counter({'T': 2, 'N': 1})
# Position 2100: Counter({'G': 2, 'N': 1})
# Position 2101: Counter({'A': 2, 'N': 1})
# Position 2102: Counter({'A': 2, 'N': 1})
# Position 2103: Counter({'G': 2, 'N': 1})
# Position 2104: Counter({'C': 2, 'N': 1})
# Position 2105: Counter({'A': 2, 'N': 1})
# Position 2106: Counter({'G': 2, 'N': 1})
# Position 2107: Counter({'C': 2, 'N': 1})
# Position 2108: Counter({'A': 2, 'N': 1})
# Position 2109: Counter({'A': 2, 'N': 1})
# Position 2110: Counter({'G': 2, 'N': 1})
# Position 2111: Counter({'T': 2, 'N': 1})
# Position 2112: Counter({'A': 2, 'N': 1})
# Position 2113: Counter({'T': 2, 'N': 1})
# Position 2114: Counter({'G': 2, 'N': 1})
# Position 2115: Counter({'A': 2, 'N': 1})
# Position 2116: Counter({'T': 2, 'N': 1})
# Position 2117: Counter({'G': 2, 'N': 1})
# Position 2118: Counter({'A': 2, 'N': 1})
# Position 2119: Counter({'G': 2, 'N': 1})
# Position 2120: Counter({'C': 2, 'N': 1})
# Position 2121: Counter({'A': 2, 'N': 1})
# Position 2122: Counter({'A': 2, 'N': 1})
# Position 2123: Counter({'G': 2, 'N': 1})
# Position 2124: Counter({'C': 2, 'N': 1})
# Position 2125: Counter({'T': 2, 'N': 1})
# Position 2126: Counter({'T': 2, 'N': 1})
# Position 2127: Counter({'T': 2, 'N': 1})
# Position 2128: Counter({'C': 2, 'N': 1})
# Position 2129: Counter({'T': 2, 'N': 1})
# Position 2130: Counter({'C': 2, 'N': 1})
# Position 2131: Counter({'A': 2, 'N': 1})
# Position 2132: Counter({'C': 2, 'N': 1})
# Position 2133: Counter({'A': 2, 'N': 1})
# Position 2134: Counter({'A': 2, 'N': 1})
# Position 2135: Counter({'G': 2, 'N': 1})
# Position 2136: Counter({'C': 2, 'N': 1})
# Position 2137: Counter({'A': 2, 'N': 1})
# Position 2138: Counter({'T': 2, 'N': 1})
# Position 2139: Counter({'T': 2, 'N': 1})
# Position 2140: Counter({'T': 2, 'N': 1})
# Position 2141: Counter({'G': 2, 'N': 1})
# Position 2142: Counter({'G': 2, 'N': 1})
# Position 2143: Counter({'T': 2, 'N': 1})
# Position 2144: Counter({'T': 2, 'N': 1})
# Position 2145: Counter({'T': 2, 'N': 1})
# Position 2146: Counter({'T': 2, 'N': 1})
# Position 2147: Counter({'A': 2, 'N': 1})
# Position 2148: Counter({'A': 2, 'N': 1})
# Position 2149: Counter({'A': 2, 'N': 1})
# Position 2150: Counter({'T': 2, 'N': 1})
# Position 2151: Counter({'T': 2, 'N': 1})
# Position 2152: Counter({'A': 2, 'N': 1})
# Position 2153: Counter({'T': 2, 'N': 1})
# Position 2154: Counter({'G': 2, 'N': 1})
# Position 2155: Counter({'G': 2, 'N': 1})
# Position 2156: Counter({'A': 2, 'N': 1})
# Position 2157: Counter({'G': 2, 'N': 1})
# Position 2158: Counter({'T': 2, 'N': 1})
# Position 2159: Counter({'A': 2, 'N': 1})
# Position 2160: Counter({'T': 2, 'N': 1})
# Position 2161: Counter({'G': 2, 'N': 1})
# Position 2162: Counter({'T': 2, 'N': 1})
# Position 2163: Counter({'G': 2, 'N': 1})
# Position 2164: Counter({'T': 2, 'N': 1})
# Position 2165: Counter({'C': 2, 'N': 1})
# Position 2166: Counter({'T': 2, 'N': 1})
# Position 2167: Counter({'G': 2, 'N': 1})
# Position 2168: Counter({'T': 2, 'N': 1})
# Position 2169: Counter({'G': 2, 'N': 1})
# Position 2170: Counter({'G': 2, 'N': 1})
# Position 2171: Counter({'A': 2, 'N': 1})
# Position 2172: Counter({'G': 2, 'N': 1})
# Position 2173: Counter({'A': 2, 'N': 1})
# Position 2174: Counter({'C': 2, 'N': 1})
# Position 2175: Counter({'G': 2, 'N': 1})
# Position 2176: Counter({'A': 2, 'N': 1})
# Position 2177: Counter({'G': 2, 'N': 1})
# Position 2178: Counter({'A': 2, 'N': 1})
# Position 2179: Counter({'A': 2, 'N': 1})
# Position 2180: Counter({'T': 2, 'N': 1})
# Position 2181: Counter({'A': 2, 'N': 1})
# Position 2182: Counter({'T': 2, 'N': 1})
# Position 2183: Counter({'T': 2, 'N': 1})
# Position 2184: Counter({'C': 2, 'N': 1})
# Position 2185: Counter({'T': 2, 'N': 1})
# Position 2186: Counter({'G': 2, 'N': 1})
# Position 2187: Counter({'G': 2, 'N': 1})
# Position 2188: Counter({'T': 2, 'N': 1})
# Position 2189: Counter({'T': 2, 'N': 1})
# Position 2190: Counter({'C': 2, 'N': 1})
# Position 2191: Counter({'A': 2, 'N': 1})
# Position 2192: Counter({'G': 2, 'N': 1})
# Position 2193: Counter({'G': 2, 'N': 1})
# Position 2194: Counter({'A': 2, 'N': 1})
# Position 2195: Counter({'G': 2, 'N': 1})
# Position 2196: Counter({'T': 2, 'N': 1})
# Position 2197: Counter({'T': 2, 'N': 1})
# Position 2198: Counter({'T': 2, 'N': 1})
# Position 2199: Counter({'G': 2, 'N': 1})
# Position 2200: Counter({'T': 2, 'N': 1})
# Position 2201: Counter({'A': 2, 'N': 1})
# Position 2202: Counter({'A': 2, 'N': 1})
# Position 2203: Counter({'A': 2, 'N': 1})
# Position 2204: Counter({'A': 2, 'N': 1})
# Position 2205: Counter({'T': 2, 'N': 1})
# Position 2206: Counter({'T': 2, 'N': 1})
# Position 2207: Counter({'T': 2, 'N': 1})
# Position 2208: Counter({'G': 2, 'N': 1})
# Position 2209: Counter({'G': 2, 'N': 1})
# Position 2210: Counter({'A': 2, 'N': 1})
# Position 2211: Counter({'T': 2, 'N': 1})
# Position 2212: Counter({'C': 2, 'N': 1})
# Position 2213: Counter({'A': 2, 'N': 1})
# Position 2214: Counter({'C': 2, 'N': 1})
# Position 2215: Counter({'T': 2, 'N': 1})
# Position 2216: Counter({'A': 2, 'N': 1})
# Position 2217: Counter({'G': 2, 'N': 1})
# Position 2218: Counter({'A': 2, 'N': 1})
# Position 2219: Counter({'T': 2, 'N': 1})
# Position 2220: Counter({'A': 2, 'N': 1})
# Position 2221: Counter({'C': 2, 'N': 1})
# Position 2222: Counter({'A': 2, 'N': 1})
# Position 2223: Counter({'T': 2, 'N': 1})
# Position 2224: Counter({'A': 2, 'N': 1})
# Position 2225: Counter({'T': 2, 'N': 1})
# Position 2226: Counter({'C': 2, 'N': 1})
# Position 2227: Counter({'T': 2, 'N': 1})
# Position 2228: Counter({'G': 2, 'N': 1})
# Position 2229: Counter({'A': 2, 'N': 1})
# Position 2230: Counter({'A': 2, 'N': 1})
# Position 2231: Counter({'A': 2, 'N': 1})
# Position 2232: Counter({'A': 2, 'N': 1})
# Position 2233: Counter({'A': 2, 'N': 1})
# Position 2234: Counter({'G': 2, 'N': 1})
# Position 2235: Counter({'A': 2, 'N': 1})
# Position 2236: Counter({'A': 2, 'N': 1})
# Position 2237: Counter({'T': 2, 'N': 1})
# Position 2238: Counter({'A': 2, 'N': 1})
# Position 2239: Counter({'A': 2, 'N': 1})
# Position 2240: Counter({'A': 2, 'N': 1})
# Position 2241: Counter({'A': 2, 'N': 1})
# Position 2242: Counter({'A': 2, 'N': 1})
# Position 2243: Counter({'T': 2, 'N': 1})
# Position 2244: Counter({'T': 2, 'N': 1})
# Position 2245: Counter({'G': 2, 'N': 1})
# Position 2246: Counter({'T': 2, 'N': 1})
# Position 2247: Counter({'A': 2, 'N': 1})
# Position 2248: Counter({'T': 2, 'N': 1})
# Position 2249: Counter({'A': 2, 'N': 1})
# Position 2250: Counter({'A': 2, 'N': 1})
# Position 2251: Counter({'A': 2, 'N': 1})
# Position 2252: Counter({'T': 2, 'N': 1})
# Position 2253: Counter({'A': 2, 'N': 1})
# Position 2254: Counter({'T': 2, 'N': 1})
# Position 2255: Counter({'A': 2, 'N': 1})
# Position 2256: Counter({'T': 2, 'N': 1})
# Position 2257: Counter({'T': 2, 'N': 1})
# Position 2258: Counter({'A': 2, 'N': 1})
# Position 2259: Counter({'T': 2, 'N': 1})
# Position 2260: Counter({'G': 2, 'N': 1})
# Position 2261: Counter({'G': 2, 'N': 1})
# Position 2262: Counter({'A': 2, 'N': 1})
# Position 2263: Counter({'A': 2, 'N': 1})
# Position 2264: Counter({'A': 2, 'N': 1})
# Position 2265: Counter({'C': 2, 'N': 1})
# Position 2266: Counter({'T': 2, 'N': 1})
# Position 2267: Counter({'T': 2, 'N': 1})
# Position 2268: Counter({'G': 2, 'N': 1})
# Position 2269: Counter({'A': 2, 'N': 1})
# Position 2270: Counter({'A': 2, 'N': 1})
# Position 2271: Counter({'G': 2, 'N': 1})
# Position 2272: Counter({'T': 2, 'N': 1})
# Position 2273: Counter({'T': 2, 'N': 1})
# Position 2274: Counter({'G': 2, 'N': 1})
# Position 2275: Counter({'C': 2, 'N': 1})
# Position 2276: Counter({'T': 2, 'N': 1})
# Position 2277: Counter({'A': 2, 'N': 1})
# Position 2278: Counter({'A': 2, 'N': 1})
# Position 2279: Counter({'A': 2, 'N': 1})
# Position 2280: Counter({'C': 2, 'N': 1})
# Position 2281: Counter({'A': 2, 'N': 1})
# Position 2282: Counter({'G': 2, 'N': 1})
# Position 2283: Counter({'T': 2, 'N': 1})
# Position 2284: Counter({'T': 2, 'N': 1})
# Position 2285: Counter({'G': 2, 'N': 1})
# Position 2286: Counter({'G': 2, 'N': 1})
# Position 2287: Counter({'C': 2, 'N': 1})
# Position 2288: Counter({'A': 2, 'N': 1})
# Position 2289: Counter({'T': 2, 'N': 1})
# Position 2290: Counter({'G': 2, 'N': 1})
# Position 2291: Counter({'G': 2, 'N': 1})
# Position 2292: Counter({'G': 2, 'N': 1})
# Position 2293: Counter({'C': 2, 'N': 1})
# Position 2294: Counter({'C': 2, 'N': 1})
# Position 2295: Counter({'A': 2, 'N': 1})
# Position 2296: Counter({'T': 2, 'N': 1})
# Position 2297: Counter({'G': 2, 'N': 1})
# Position 2298: Counter({'C': 2, 'N': 1})
# Position 2299: Counter({'A': 2, 'N': 1})
# Position 2300: Counter({'T': 2, 'N': 1})
# Position 2301: Counter({'T': 2, 'N': 1})
# Position 2302: Counter({'T': 2, 'N': 1})
# Position 2303: Counter({'T': 2, 'N': 1})
# Position 2304: Counter({'C': 2, 'N': 1})
# Position 2305: Counter({'T': 2, 'N': 1})
# Position 2306: Counter({'A': 2, 'N': 1})
# Position 2307: Counter({'G': 2, 'N': 1})
# Position 2308: Counter({'A': 2, 'N': 1})
# Position 2309: Counter({'A': 2, 'N': 1})
# Position 2310: Counter({'G': 2, 'N': 1})
# Position 2311: Counter({'A': 2, 'N': 1})
# Position 2312: Counter({'A': 2, 'N': 1})
# Position 2313: Counter({'A': 2, 'N': 1})
# Position 2314: Counter({'A': 2, 'N': 1})
# Position 2315: Counter({'C': 2, 'N': 1})
# Position 2316: Counter({'A': 2, 'N': 1})
# Position 2317: Counter({'C': 2, 'N': 1})
# Position 2318: Counter({'C': 2, 'N': 1})
# Position 2319: Counter({'C': 2, 'N': 1})
# Position 2320: Counter({'T': 2, 'N': 1})
# Position 2321: Counter({'T': 2, 'N': 1})
# Position 2322: Counter({'A': 2, 'N': 1})
# Position 2323: Counter({'T': 2, 'N': 1})
# Position 2324: Counter({'T': 2, 'N': 1})
# Position 2325: Counter({'C': 2, 'N': 1})
# Position 2326: Counter({'A': 2, 'N': 1})
# Position 2327: Counter({'T': 2, 'N': 1})
# Position 2328: Counter({'G': 2, 'N': 1})
# Position 2329: Counter({'G': 2, 'N': 1})
# Position 2330: Counter({'G': 2, 'N': 1})
# Position 2331: Counter({'A': 2, 'N': 1})
# Position 2332: Counter({'A': 2, 'N': 1})
# Position 2333: Counter({'T': 2, 'N': 1})
# Position 2334: Counter({'G': 2, 'N': 1})
# Position 2335: Counter({'T': 2, 'N': 1})
# Position 2336: Counter({'A': 2, 'N': 1})
# Position 2337: Counter({'T': 2, 'N': 1})
# Position 2338: Counter({'G': 2, 'N': 1})
# Position 2339: Counter({'T': 2, 'N': 1})
# Position 2340: Counter({'G': 2, 'N': 1})
# Position 2341: Counter({'C': 2, 'N': 1})
# Position 2342: Counter({'C': 2, 'N': 1})
# Position 2343: Counter({'A': 2, 'N': 1})
# Position 2344: Counter({'A': 2, 'N': 1})
# Position 2345: Counter({'A': 2, 'N': 1})
# Position 2346: Counter({'A': 2, 'N': 1})
# Position 2347: Counter({'A': 2, 'N': 1})
# Position 2348: Counter({'T': 2, 'N': 1})
# Position 2349: Counter({'A': 2, 'N': 1})
# Position 2350: Counter({'T': 2, 'N': 1})
# Position 2351: Counter({'T': 2, 'N': 1})
# Position 2352: Counter({'C': 2, 'N': 1})
# Position 2353: Counter({'T': 2, 'N': 1})
# Position 2354: Counter({'G': 2, 'N': 1})
# Position 2355: Counter({'C': 2, 'N': 1})
# Position 2356: Counter({'T': 2, 'N': 1})
# Position 2357: Counter({'T': 2, 'N': 1})
# Position 2358: Counter({'A': 2, 'N': 1})
# Position 2359: Counter({'T': 2, 'N': 1})
# Position 2360: Counter({'C': 2, 'N': 1})
# Position 2361: Counter({'A': 2, 'N': 1})
# Position 2362: Counter({'G': 2, 'N': 1})
# Position 2363: Counter({'A': 2, 'N': 1})
# Position 2364: Counter({'G': 2, 'N': 1})
# Position 2365: Counter({'A': 2, 'N': 1})
# Position 2366: Counter({'A': 2, 'N': 1})
# Position 2367: Counter({'G': 2, 'N': 1})
# Position 2368: Counter({'A': 2, 'N': 1})
# Position 2369: Counter({'A': 2, 'N': 1})
# Position 2370: Counter({'G': 2, 'N': 1})
# Position 2371: Counter({'A': 2, 'N': 1})
# Position 2372: Counter({'C': 2, 'N': 1})
# Position 2373: Counter({'A': 2, 'N': 1})
# Position 2374: Counter({'G': 2, 'N': 1})
# Position 2375: Counter({'G': 2, 'N': 1})
# Position 2376: Counter({'A': 2, 'N': 1})
# Position 2377: Counter({'A': 2, 'N': 1})
# Position 2378: Counter({'G': 2, 'N': 1})
# Position 2379: Counter({'A': 2, 'N': 1})
# Position 2380: Counter({'C': 2, 'N': 1})
# Position 2381: Counter({'A': 2, 'N': 1})
# Position 2382: Counter({'G': 2, 'N': 1})
# Position 2383: Counter({'G': 2, 'N': 1})
# Position 2384: Counter({'A': 2, 'N': 1})
# Position 2385: Counter({'A': 2, 'N': 1})
# Position 2386: Counter({'A': 2, 'N': 1})
# Position 2387: Counter({'T': 2, 'N': 1})
# Position 2388: Counter({'C': 2, 'N': 1})
# Position 2389: Counter({'C': 2, 'N': 1})
# Position 2390: Counter({'T': 2, 'N': 1})
# Position 2391: Counter({'C': 2, 'N': 1})
# Position 2392: Counter({'C': 2, 'N': 1})
# Position 2393: Counter({'T': 2, 'N': 1})
# Position 2394: Counter({'T': 2, 'N': 1})
# Position 2395: Counter({'T': 2, 'N': 1})
# Position 2396: Counter({'C': 2, 'N': 1})
# Position 2397: Counter({'A': 2, 'N': 1})
# Position 2398: Counter({'T': 2, 'N': 1})
# Position 2399: Counter({'C': 2, 'N': 1})
# Position 2400: Counter({'A': 2, 'N': 1})
# Position 2401: Counter({'A': 2, 'N': 1})
# Position 2402: Counter({'A': 2, 'N': 1})
# Position 2403: Counter({'C': 2, 'N': 1})
# Position 2404: Counter({'T': 2, 'N': 1})
# Position 2405: Counter({'T': 2, 'N': 1})
# Position 2406: Counter({'A': 2, 'N': 1})
# Position 2407: Counter({'G': 2, 'N': 1})
# Position 2408: Counter({'T': 2, 'N': 1})
# Position 2409: Counter({'G': 2, 'N': 1})
# Position 2410: Counter({'A': 2, 'N': 1})
# Position 2411: Counter({'T': 2, 'N': 1})
# Position 2412: Counter({'C': 2, 'N': 1})
# Position 2413: Counter({'C': 2, 'N': 1})
# Position 2414: Counter({'T': 2, 'N': 1})
# Position 2415: Counter({'G': 2, 'N': 1})
# Position 2416: Counter({'G': 2, 'N': 1})
# Position 2417: Counter({'C': 2, 'N': 1})
# Position 2418: Counter({'A': 2, 'N': 1})
# Position 2419: Counter({'T': 2, 'N': 1})
# Position 2420: Counter({'T': 2, 'N': 1})
# Position 2421: Counter({'A': 2, 'N': 1})
# Position 2422: Counter({'G': 2, 'N': 1})
# Position 2423: Counter({'T': 2, 'N': 1})
# Position 2424: Counter({'A': 2, 'N': 1})
# Position 2425: Counter({'T': 2, 'N': 1})
# Position 2426: Counter({'T': 2, 'N': 1})
# Position 2427: Counter({'A': 2, 'N': 1})
# Position 2428: Counter({'C': 2, 'N': 1})
# Position 2429: Counter({'A': 2, 'N': 1})
# Position 2430: Counter({'G': 2, 'N': 1})
# Position 2431: Counter({'T': 2, 'N': 1})
# Position 2432: Counter({'T': 2, 'N': 1})
# Position 2433: Counter({'T': 2, 'N': 1})
# Position 2434: Counter({'T': 2, 'N': 1})
# Position 2435: Counter({'G': 2, 'N': 1})
# Position 2436: Counter({'C': 2, 'N': 1})
# Position 2437: Counter({'C': 2, 'N': 1})
# Position 2438: Counter({'A': 2, 'N': 1})
# Position 2439: Counter({'A': 2, 'N': 1})
# Position 2440: Counter({'A': 2, 'N': 1})
# Position 2441: Counter({'G': 2, 'N': 1})
# Position 2442: Counter({'G': 2, 'N': 1})
# Position 2443: Counter({'A': 2, 'N': 1})
# Position 2444: Counter({'C': 2, 'N': 1})
# Position 2445: Counter({'A': 2, 'N': 1})
# Position 2446: Counter({'T': 2, 'N': 1})
# Position 2447: Counter({'T': 2, 'N': 1})
# Position 2448: Counter({'C': 2, 'N': 1})
# Position 2449: Counter({'T': 2, 'N': 1})
# Position 2450: Counter({'T': 2, 'N': 1})
# Position 2451: Counter({'C': 2, 'N': 1})
# Position 2452: Counter({'A': 2, 'N': 1})
# Position 2453: Counter({'G': 2, 'N': 1})
# Position 2454: Counter({'G': 2, 'N': 1})
# Position 2455: Counter({'A': 2, 'N': 1})
# Position 2456: Counter({'G': 2, 'N': 1})
# Position 2457: Counter({'A': 2, 'N': 1})
# Position 2458: Counter({'G': 2, 'N': 1})
# Position 2459: Counter({'A': 2, 'N': 1})
# Position 2460: Counter({'A': 2, 'N': 1})
# Position 2461: Counter({'T': 2, 'N': 1})
# Position 2462: Counter({'A': 2, 'N': 1})
# Position 2463: Counter({'C': 2, 'N': 1})
# Position 2464: Counter({'C': 2, 'N': 1})
# Position 2465: Counter({'A': 2, 'N': 1})
# Position 2466: Counter({'T': 2, 'N': 1})
# Position 2467: Counter({'G': 2, 'N': 1})
# Position 2468: Counter({'G': 2, 'N': 1})
# Position 2469: Counter({'G': 2, 'N': 1})
# Position 2470: Counter({'T': 2, 'N': 1})
# Position 2471: Counter({'A': 2, 'N': 1})
# Position 2472: Counter({'C': 2, 'N': 1})
# Position 2473: Counter({'C': 2, 'N': 1})
# Position 2474: Counter({'A': 2, 'N': 1})
# Position 2475: Counter({'C': 2, 'N': 1})
# Position 2476: Counter({'C': 2, 'N': 1})
# Position 2477: Counter({'T': 2, 'N': 1})
# Position 2478: Counter({'G': 2, 'N': 1})
# Position 2479: Counter({'A': 2, 'N': 1})
# Position 2480: Counter({'A': 2, 'N': 1})
# Position 2481: Counter({'T': 2, 'N': 1})
# Position 2482: Counter({'G': 2, 'N': 1})
# Position 2483: Counter({'C': 2, 'N': 1})
# Position 2484: Counter({'A': 2, 'N': 1})
# Position 2485: Counter({'T': 2, 'N': 1})
# Position 2486: Counter({'T': 2, 'N': 1})
# Position 2487: Counter({'G': 2, 'N': 1})
# Position 2488: Counter({'A': 2, 'N': 1})
# Position 2489: Counter({'A': 2, 'N': 1})
# Position 2490: Counter({'A': 2, 'N': 1})
# Position 2491: Counter({'A': 2, 'N': 1})
# Position 2492: Counter({'T': 2, 'N': 1})
# Position 2493: Counter({'C': 2, 'N': 1})
# Position 2494: Counter({'C': 2, 'N': 1})
# Position 2495: Counter({'T': 2, 'N': 1})
# Position 2496: Counter({'A': 2, 'N': 1})
# Position 2497: Counter({'A': 2, 'N': 1})
# Position 2498: Counter({'A': 2, 'N': 1})
# Position 2499: Counter({'A': 2, 'N': 1})
# Position 2500: Counter({'A': 2, 'N': 1})
# Position 2501: Counter({'T': 2, 'N': 1})
# Position 2502: Counter({'T': 2, 'N': 1})
# Position 2503: Counter({'T': 2, 'N': 1})
# Position 2504: Counter({'A': 2, 'N': 1})
# Position 2505: Counter({'A': 2, 'N': 1})
# Position 2506: Counter({'A': 2, 'N': 1})
# Position 2507: Counter({'T': 2, 'N': 1})
# Position 2508: Counter({'T': 2, 'N': 1})
# Position 2509: Counter({'T': 2, 'N': 1})
# Position 2510: Counter({'G': 2, 'N': 1})
# Position 2511: Counter({'G': 2, 'N': 1})
# Position 2512: Counter({'C': 2, 'N': 1})
# Position 2513: Counter({'A': 2, 'N': 1})
# Position 2514: Counter({'A': 2, 'N': 1})
# Position 2515: Counter({'C': 2, 'N': 1})
# Position 2516: Counter({'A': 2, 'N': 1})
# Position 2517: Counter({'G': 2, 'N': 1})
# Position 2518: Counter({'A': 2, 'N': 1})
# Position 2519: Counter({'C': 2, 'N': 1})
# Position 2520: Counter({'A': 2, 'N': 1})
# Position 2521: Counter({'A': 2, 'N': 1})
# Position 2522: Counter({'A': 2, 'N': 1})
# Position 2523: Counter({'T': 2, 'N': 1})
# Position 2524: Counter({'G': 2, 'N': 1})
# Position 2525: Counter({'G': 2, 'N': 1})
# Position 2526: Counter({'A': 2, 'N': 1})
# Position 2527: Counter({'G': 2, 'N': 1})
# Position 2528: Counter({'T': 2, 'N': 1})
# Position 2529: Counter({'T': 2, 'N': 1})
# Position 2530: Counter({'T': 2, 'N': 1})
# Position 2531: Counter({'T': 2, 'N': 1})
# Position 2532: Counter({'G': 2, 'N': 1})
# Position 2533: Counter({'G': 2, 'N': 1})
# Position 2534: Counter({'T': 2, 'N': 1})
# Position 2535: Counter({'A': 2, 'N': 1})
# Position 2536: Counter({'C': 2, 'N': 1})
# Position 2537: Counter({'C': 2, 'N': 1})
# Position 2538: Counter({'A': 2, 'N': 1})
# Position 2539: Counter({'C': 2, 'N': 1})
# Position 2540: Counter({'T': 2, 'N': 1})
# Position 2541: Counter({'T': 2, 'N': 1})
# Position 2542: Counter({'T': 2, 'N': 1})
# Position 2543: Counter({'G': 2, 'N': 1})
# Position 2544: Counter({'T': 2, 'N': 1})
# Position 2545: Counter({'G': 2, 'N': 1})
# Position 2546: Counter({'G': 2, 'N': 1})
# Position 2547: Counter({'G': 2, 'N': 1})
# Position 2548: Counter({'A': 2, 'N': 1})
# Position 2549: Counter({'A': 2, 'N': 1})
# Position 2550: Counter({'A': 2, 'N': 1})
# Position 2551: Counter({'T': 2, 'N': 1})
# Position 2552: Counter({'C': 2, 'N': 1})
# Position 2553: Counter({'T': 2, 'N': 1})
# Position 2554: Counter({'G': 2, 'N': 1})
# Position 2555: Counter({'C': 2, 'N': 1})
# Position 2556: Counter({'A': 2, 'N': 1})
# Position 2557: Counter({'G': 2, 'N': 1})
# Position 2558: Counter({'T': 2, 'N': 1})
# Position 2559: Counter({'G': 2, 'N': 1})
# Position 2560: Counter({'G': 2, 'N': 1})
# Position 2561: Counter({'A': 2, 'N': 1})
# Position 2562: Counter({'G': 2, 'N': 1})
# Position 2563: Counter({'G': 2, 'N': 1})
# Position 2564: Counter({'A': 2, 'N': 1})
# Position 2565: Counter({'G': 2, 'N': 1})
# Position 2566: Counter({'A': 2, 'N': 1})
# Position 2567: Counter({'T': 2, 'N': 1})
# Position 2568: Counter({'A': 2, 'N': 1})
# Position 2569: Counter({'A': 2, 'N': 1})
# Position 2570: Counter({'A': 2, 'N': 1})
# Position 2571: Counter({'C': 2, 'N': 1})
# Position 2572: Counter({'C': 2, 'N': 1})
# Position 2573: Counter({'T': 2, 'N': 1})
# Position 2574: Counter({'C': 2, 'N': 1})
# Position 2575: Counter({'T': 2, 'N': 1})
# Position 2576: Counter({'A': 2, 'N': 1})
# Position 2577: Counter({'A': 2, 'N': 1})
# Position 2578: Counter({'G': 2, 'N': 1})
# Position 2579: Counter({'T': 2, 'N': 1})
# Position 2580: Counter({'G': 2, 'N': 1})
# Position 2581: Counter({'C': 2, 'N': 1})
# Position 2582: Counter({'T': 2, 'N': 1})
# Position 2583: Counter({'C': 2, 'N': 1})
# Position 2584: Counter({'T': 2, 'N': 1})
# Position 2585: Counter({'G': 2, 'N': 1})
# Position 2586: Counter({'G': 2, 'N': 1})
# Position 2587: Counter({'A': 2, 'N': 1})
# Position 2588: Counter({'T': 2, 'N': 1})
# Position 2589: Counter({'T': 2, 'N': 1})
# Position 2590: Counter({'C': 2, 'N': 1})
# Position 2591: Counter({'T': 2, 'N': 1})
# Position 2592: Counter({'C': 2, 'N': 1})
# Position 2593: Counter({'A': 2, 'N': 1})
# Position 2594: Counter({'A': 2, 'N': 1})
# Position 2595: Counter({'A': 2, 'N': 1})
# Position 2596: Counter({'G': 2, 'N': 1})
# Position 2597: Counter({'A': 2, 'N': 1})
# Position 2598: Counter({'A': 2, 'N': 1})
# Position 2599: Counter({'A': 2, 'N': 1})
# Position 2600: Counter({'G': 2, 'N': 1})
# Position 2601: Counter({'C': 2, 'N': 1})
# Position 2602: Counter({'T': 2, 'N': 1})
# Position 2603: Counter({'A': 2, 'N': 1})
# Position 2604: Counter({'C': 2, 'N': 1})
# Position 2605: Counter({'A': 2, 'N': 1})
# Position 2606: Counter({'A': 2, 'N': 1})
# Position 2607: Counter({'T': 2, 'N': 1})
# Position 2608: Counter({'T': 2, 'N': 1})
# Position 2609: Counter({'T': 2, 'N': 1})
# Position 2610: Counter({'T': 2, 'N': 1})
# Position 2611: Counter({'A': 2, 'N': 1})
# Position 2612: Counter({'T': 2, 'N': 1})
# Position 2613: Counter({'G': 2, 'N': 1})
# Position 2614: Counter({'A': 2, 'N': 1})
# Position 2615: Counter({'A': 2, 'N': 1})
# Position 2616: Counter({'G': 2, 'N': 1})
# Position 2617: Counter({'A': 2, 'N': 1})
# Position 2618: Counter({'T': 2, 'N': 1})
# Position 2619: Counter({'A': 2, 'N': 1})
# Position 2620: Counter({'G': 2, 'N': 1})
# Position 2621: Counter({'G': 2, 'N': 1})
# Position 2622: Counter({'C': 2, 'N': 1})
# Position 2623: Counter({'A': 2, 'N': 1})
# Position 2624: Counter({'T': 2, 'N': 1})
# Position 2625: Counter({'C': 2, 'N': 1})
# Position 2626: Counter({'A': 2, 'N': 1})
# Position 2627: Counter({'G': 2, 'N': 1})
# Position 2628: Counter({'C': 2, 'N': 1})
# Position 2629: Counter({'T': 2, 'N': 1})
# Position 2630: Counter({'T': 2, 'N': 1})
# Position 2631: Counter({'C': 2, 'N': 1})
# Position 2632: Counter({'C': 2, 'N': 1})
# Position 2633: Counter({'T': 2, 'N': 1})
# Position 2634: Counter({'G': 2, 'N': 1})
# Position 2635: Counter({'C': 2, 'N': 1})
# Position 2636: Counter({'A': 2, 'N': 1})
# Position 2637: Counter({'C': 2, 'N': 1})
# Position 2638: Counter({'C': 2, 'N': 1})
# Position 2639: Counter({'A': 2, 'N': 1})
# Position 2640: Counter({'A': 2, 'N': 1})
# Position 2641: Counter({'A': 2, 'N': 1})
# Position 2642: Counter({'G': 2, 'N': 1})
# Position 2643: Counter({'T': 2, 'N': 1})
# Position 2644: Counter({'G': 2, 'N': 1})
# Position 2645: Counter({'G': 2, 'N': 1})
# Position 2646: Counter({'G': 2, 'N': 1})
# Position 2647: Counter({'C': 2, 'N': 1})
# Position 2648: Counter({'A': 2, 'N': 1})
# Position 2649: Counter({'G': 2, 'N': 1})
# Position 2650: Counter({'A': 2, 'N': 1})
# Position 2651: Counter({'A': 2, 'N': 1})
# Position 2652: Counter({'T': 2, 'N': 1})
# Position 2653: Counter({'T': 2, 'N': 1})
# Position 2654: Counter({'A': 2, 'N': 1})
# Position 2655: Counter({'G': 2, 'N': 1})
# Position 2656: Counter({'C': 2, 'N': 1})
# Position 2657: Counter({'A': 2, 'N': 1})
# Position 2658: Counter({'A': 2, 'N': 1})
# Position 2659: Counter({'A': 2, 'N': 1})
# Position 2660: Counter({'C': 2, 'N': 1})
# Position 2661: Counter({'C': 2, 'N': 1})
# Position 2662: Counter({'T': 2, 'N': 1})
# Position 2663: Counter({'T': 2, 'N': 1})
# Position 2664: Counter({'A': 2, 'N': 1})
# Position 2665: Counter({'T': 2, 'N': 1})
# Position 2666: Counter({'A': 2, 'N': 1})
# Position 2667: Counter({'A': 2, 'N': 1})
# Position 2668: Counter({'A': 2, 'N': 1})
# Position 2669: Counter({'T': 2, 'N': 1})
# Position 2670: Counter({'A': 2, 'N': 1})
# Position 2671: Counter({'A': 2, 'N': 1})
# Position 2672: Counter({'T': 2, 'N': 1})
# Position 2673: Counter({'T': 2, 'N': 1})
# Position 2674: Counter({'G': 2, 'N': 1})
# Position 2675: Counter({'T': 2, 'N': 1})
# Position 2676: Counter({'A': 2, 'N': 1})
# Position 2677: Counter({'T': 2, 'N': 1})
# Position 2678: Counter({'G': 2, 'N': 1})
# Position 2679: Counter({'G': 2, 'N': 1})
# Position 2680: Counter({'A': 2, 'N': 1})
# Position 2681: Counter({'T': 2, 'N': 1})
# Position 2682: Counter({'T': 2, 'N': 1})
# Position 2683: Counter({'A': 2, 'N': 1})
# Position 2684: Counter({'T': 2, 'N': 1})
# Position 2685: Counter({'G': 2, 'N': 1})
# Position 2686: Counter({'A': 2, 'N': 1})
# Position 2687: Counter({'A': 2, 'N': 1})
# Position 2688: Counter({'C': 2, 'N': 1})
# Position 2689: Counter({'C': 2, 'N': 1})
# Position 2690: Counter({'A': 2, 'N': 1})
# Position 2691: Counter({'G': 2, 'N': 1})
# Position 2692: Counter({'A': 2, 'N': 1})
# Position 2693: Counter({'T': 2, 'N': 1})
# Position 2694: Counter({'T': 2, 'N': 1})
# Position 2695: Counter({'T': 2, 'N': 1})
# Position 2696: Counter({'C': 2, 'N': 1})
# Position 2697: Counter({'A': 2, 'N': 1})
# Position 2698: Counter({'G': 2, 'N': 1})
# Position 2699: Counter({'G': 2, 'N': 1})
# Position 2700: Counter({'C': 2, 'N': 1})
# Position 2701: Counter({'C': 2, 'N': 1})
# Position 2702: Counter({'T': 2, 'N': 1})
# Position 2703: Counter({'T': 2, 'N': 1})
# Position 2704: Counter({'C': 2, 'N': 1})
# Position 2705: Counter({'T': 2, 'N': 1})
# Position 2706: Counter({'T': 2, 'N': 1})
# Position 2707: Counter({'T': 2, 'N': 1})
# Position 2708: Counter({'C': 2, 'N': 1})
# Position 2709: Counter({'A': 2, 'N': 1})
# Position 2710: Counter({'G': 2, 'N': 1})
# Position 2711: Counter({'A': 2, 'N': 1})
# Position 2712: Counter({'G': 2, 'N': 1})
# Position 2713: Counter({'C': 2, 'N': 1})
# Position 2714: Counter({'C': 2, 'N': 1})
# Position 2715: Counter({'A': 2, 'N': 1})
# Position 2716: Counter({'T': 2, 'N': 1})
# Position 2717: Counter({'C': 2, 'N': 1})
# Position 2718: Counter({'A': 2, 'N': 1})
# Position 2719: Counter({'T': 2, 'N': 1})
# Position 2720: Counter({'A': 2, 'N': 1})
# Position 2721: Counter({'C': 2, 'N': 1})
# Position 2722: Counter({'G': 2, 'N': 1})
# Position 2723: Counter({'A': 2, 'N': 1})
# Position 2724: Counter({'G': 2, 'N': 1})
# Position 2725: Counter({'A': 2, 'N': 1})
# Position 2726: Counter({'T': 2, 'N': 1})
# Position 2727: Counter({'C': 2, 'N': 1})
# Position 2728: Counter({'T': 2, 'N': 1})
# Position 2729: Counter({'T': 2, 'N': 1})
# Position 2730: Counter({'A': 2, 'N': 1})
# Position 2731: Counter({'A': 2, 'N': 1})
# Position 2732: Counter({'C': 2, 'N': 1})
# Position 2733: Counter({'A': 2, 'N': 1})
# Position 2734: Counter({'G': 2, 'N': 1})
# Position 2735: Counter({'T': 2, 'N': 1})
# Position 2736: Counter({'T': 2, 'N': 1})
# Position 2737: Counter({'T': 2, 'N': 1})
# Position 2738: Counter({'G': 2, 'N': 1})
# Position 2739: Counter({'T': 2, 'N': 1})
# Position 2740: Counter({'T': 2, 'N': 1})
# Position 2741: Counter({'T': 2, 'N': 1})
# Position 2742: Counter({'A': 2, 'N': 1})
# Position 2743: Counter({'C': 2, 'N': 1})
# Position 2744: Counter({'T': 2, 'N': 1})
# Position 2745: Counter({'C': 2, 'N': 1})
# Position 2746: Counter({'C': 2, 'N': 1})
# Position 2747: Counter({'A': 2, 'N': 1})
# Position 2748: Counter({'G': 2, 'N': 1})
# Position 2749: Counter({'A': 2, 'N': 1})
# Position 2750: Counter({'T': 2, 'N': 1})
# Position 2751: Counter({'T': 2, 'N': 1})
# Position 2752: Counter({'A': 2, 'N': 1})
# Position 2753: Counter({'T': 2, 'N': 1})
# Position 2754: Counter({'G': 2, 'N': 1})
# Position 2755: Counter({'A': 2, 'N': 1})
# Position 2756: Counter({'A': 2, 'N': 1})
# Position 2757: Counter({'C': 2, 'N': 1})
# Position 2758: Counter({'T': 2, 'N': 1})
# Position 2759: Counter({'A': 2, 'N': 1})
# Position 2760: Counter({'T': 2, 'N': 1})
# Position 2761: Counter({'T': 2, 'N': 1})
# Position 2762: Counter({'A': 2, 'N': 1})
# Position 2763: Counter({'A': 2, 'N': 1})
# Position 2764: Counter({'C': 2, 'N': 1})
# Position 2765: Counter({'A': 2, 'N': 1})
# Position 2766: Counter({'G': 2, 'N': 1})
# Position 2767: Counter({'A': 2, 'N': 1})
# Position 2768: Counter({'A': 2, 'N': 1})
# Position 2769: Counter({'A': 2, 'N': 1})
# Position 2770: Counter({'A': 2, 'N': 1})
# Position 2771: Counter({'T': 2, 'N': 1})
# Position 2772: Counter({'G': 2, 'N': 1})
# Position 2773: Counter({'A': 2, 'N': 1})
# Position 2774: Counter({'C': 2, 'N': 1})
# Position 2775: Counter({'A': 2, 'N': 1})
# Position 2776: Counter({'T': 2, 'N': 1})
# Position 2777: Counter({'G': 2, 'N': 1})
# Position 2778: Counter({'T': 2, 'N': 1})
# Position 2779: Counter({'T': 2, 'N': 1})
# Position 2780: Counter({'A': 2, 'N': 1})
# Position 2781: Counter({'C': 2, 'N': 1})
# Position 2782: Counter({'C': 2, 'N': 1})
# Position 2783: Counter({'A': 2, 'N': 1})
# Position 2784: Counter({'A': 2, 'N': 1})
# Position 2785: Counter({'A': 2, 'N': 1})
# Position 2786: Counter({'T': 2, 'N': 1})
# Position 2787: Counter({'A': 2, 'N': 1})
# Position 2788: Counter({'T': 2, 'N': 1})
# Position 2789: Counter({'G': 2, 'N': 1})
# Position 2790: Counter({'A': 2, 'N': 1})
# Position 2791: Counter({'G': 2, 'N': 1})
# Position 2792: Counter({'G': 2, 'N': 1})
# Position 2793: Counter({'A': 2, 'N': 1})
# Position 2794: Counter({'T': 2, 'N': 1})
# Position 2795: Counter({'A': 2, 'N': 1})
# Position 2796: Counter({'G': 2, 'N': 1})
# Position 2797: Counter({'G': 2, 'N': 1})
# Position 2798: Counter({'T': 2, 'N': 1})
# Position 2799: Counter({'G': 2, 'N': 1})
# Position 2800: Counter({'C': 2, 'N': 1})
# Position 2801: Counter({'C': 2, 'N': 1})
# Position 2802: Counter({'C': 2, 'N': 1})
# Position 2803: Counter({'T': 2, 'N': 1})
# Position 2804: Counter({'G': 2, 'N': 1})
# Position 2805: Counter({'G': 2, 'N': 1})
# Position 2806: Counter({'G': 2, 'N': 1})
# Position 2807: Counter({'G': 2, 'N': 1})
# Position 2808: Counter({'T': 2, 'N': 1})
# Position 2809: Counter({'T': 2, 'N': 1})
# Position 2810: Counter({'T': 2, 'N': 1})
# Position 2811: Counter({'T': 2, 'N': 1})
# Position 2812: Counter({'C': 2, 'N': 1})
# Position 2813: Counter({'T': 2, 'N': 1})
# Position 2814: Counter({'G': 2, 'N': 1})
# Position 2815: Counter({'G': 2, 'N': 1})
# Position 2816: Counter({'T': 2, 'N': 1})
# Position 2817: Counter({'G': 2, 'N': 1})
# Position 2818: Counter({'C': 2, 'N': 1})
# Position 2819: Counter({'C': 2, 'N': 1})
# Position 2820: Counter({'T': 2, 'N': 1})
# Position 2821: Counter({'T': 2, 'N': 1})
# Position 2822: Counter({'T': 2, 'N': 1})
# Position 2823: Counter({'G': 2, 'N': 1})
# Position 2824: Counter({'A': 2, 'N': 1})
# Position 2825: Counter({'A': 2, 'N': 1})
# Position 2826: Counter({'G': 2, 'N': 1})
# Position 2827: Counter({'A': 2, 'N': 1})
# Position 2828: Counter({'C': 2, 'N': 1})
# Position 2829: Counter({'C': 2, 'N': 1})
# Position 2830: Counter({'G': 2, 'N': 1})
# Position 2831: Counter({'G': 2, 'N': 1})
# Position 2832: Counter({'G': 2, 'N': 1})
# Position 2833: Counter({'A': 2, 'N': 1})
# Position 2834: Counter({'T': 2, 'N': 1})
# Position 2835: Counter({'C': 2, 'N': 1})
# Position 2836: Counter({'C': 2, 'N': 1})
# Position 2837: Counter({'T': 2, 'N': 1})
# Position 2838: Counter({'A': 2, 'N': 1})
# Position 2839: Counter({'C': 2, 'N': 1})
# Position 2840: Counter({'A': 2, 'N': 1})
# Position 2841: Counter({'C': 2, 'N': 1})
# Position 2842: Counter({'A': 2, 'N': 1})
# Position 2843: Counter({'G': 2, 'N': 1})
# Position 2844: Counter({'T': 2, 'N': 1})
# Position 2845: Counter({'T': 2, 'N': 1})
# Position 2846: Counter({'T': 2, 'N': 1})
# Position 2847: Counter({'G': 2, 'N': 1})
# Position 2848: Counter({'A': 2, 'N': 1})
# Position 2849: Counter({'A': 2, 'N': 1})
# Position 2850: Counter({'G': 2, 'N': 1})
# Position 2851: Counter({'A': 2, 'N': 1})
# Position 2852: Counter({'G': 2, 'N': 1})
# Position 2853: Counter({'A': 2, 'N': 1})
# Position 2854: Counter({'G': 2, 'N': 1})
# Position 2855: Counter({'A': 2, 'N': 1})
# Position 2856: Counter({'C': 2, 'N': 1})
# Position 2857: Counter({'A': 2, 'N': 1})
# Position 2858: Counter({'T': 2, 'N': 1})
# Position 2859: Counter({'T': 2, 'N': 1})
# Position 2860: Counter({'T': 2, 'N': 1})
# Position 2861: Counter({'G': 2, 'N': 1})
# Position 2862: Counter({'A': 2, 'N': 1})
# Position 2863: Counter({'A': 2, 'N': 1})
# Position 2864: Counter({'A': 2, 'N': 1})
# Position 2865: Counter({'T': 2, 'N': 1})
# Position 2866: Counter({'T': 2, 'N': 1})
# Position 2867: Counter({'T': 2, 'N': 1})
# Position 2868: Counter({'C': 2, 'N': 1})
# Position 2869: Counter({'T': 2, 'N': 1})
# Position 2870: Counter({'A': 2, 'N': 1})
# Position 2871: Counter({'C': 2, 'N': 1})
# Position 2872: Counter({'A': 2, 'N': 1})
# Position 2873: Counter({'G': 2, 'N': 1})
# Position 2874: Counter({'C': 2, 'N': 1})
# Position 2875: Counter({'A': 2, 'N': 1})
# Position 2876: Counter({'A': 2, 'N': 1})
# Position 2877: Counter({'C': 2, 'N': 1})
# Position 2878: Counter({'T': 2, 'N': 1})
# Position 2879: Counter({'T': 2, 'N': 1})
# Position 2880: Counter({'G': 2, 'N': 1})
# Position 2881: Counter({'G': 2, 'N': 1})
# Position 2882: Counter({'C': 2, 'N': 1})
# Position 2883: Counter({'A': 2, 'N': 1})
# Position 2884: Counter({'A': 2, 'N': 1})
# Position 2885: Counter({'G': 2, 'N': 1})
# Position 2886: Counter({'G': 2, 'N': 1})
# Position 2887: Counter({'G': 2, 'N': 1})
# Position 2888: Counter({'T': 2, 'N': 1})
# Position 2889: Counter({'A': 2, 'N': 1})
# Position 2890: Counter({'A': 2, 'N': 1})
# Position 2891: Counter({'T': 2, 'N': 1})
# Position 2892: Counter({'T': 2, 'N': 1})
# Position 2893: Counter({'T': 2, 'N': 1})
# Position 2894: Counter({'T': 2, 'N': 1})
# Position 2895: Counter({'G': 2, 'N': 1})
# Position 2896: Counter({'G': 2, 'N': 1})
# Position 2897: Counter({'G': 2, 'N': 1})
# Position 2898: Counter({'A': 2, 'N': 1})
# Position 2899: Counter({'G': 2, 'N': 1})
# Position 2900: Counter({'T': 2, 'N': 1})
# Position 2901: Counter({'G': 2, 'N': 1})
# Position 2902: Counter({'T': 2, 'N': 1})
# Position 2903: Counter({'G': 2, 'N': 1})
# Position 2904: Counter({'G': 2, 'N': 1})
# Position 2905: Counter({'A': 2, 'N': 1})
# Position 2906: Counter({'G': 2, 'N': 1})
# Position 2907: Counter({'A': 2, 'N': 1})
# Position 2908: Counter({'T': 2, 'N': 1})
# Position 2909: Counter({'G': 2, 'N': 1})
# Position 2910: Counter({'T': 2, 'N': 1})
# Position 2911: Counter({'G': 2, 'N': 1})
# Position 2912: Counter({'C': 2, 'N': 1})
# Position 2913: Counter({'C': 2, 'N': 1})
# Position 2914: Counter({'G': 2, 'N': 1})
# Position 2915: Counter({'G': 2, 'N': 1})
# Position 2916: Counter({'T': 2, 'N': 1})
# Position 2917: Counter({'A': 2, 'N': 1})
# Position 2918: Counter({'T': 2, 'N': 1})
# Position 2919: Counter({'G': 2, 'N': 1})
# Position 2920: Counter({'A': 2, 'N': 1})
# Position 2921: Counter({'C': 2, 'N': 1})
# Position 2922: Counter({'C': 2, 'N': 1})
# Position 2923: Counter({'C': 2, 'N': 1})
# Position 2924: Counter({'T': 2, 'N': 1})
# Position 2925: Counter({'C': 2, 'N': 1})
# Position 2926: Counter({'T': 2, 'N': 1})
# Position 2927: Counter({'A': 2, 'N': 1})
# Position 2928: Counter({'C': 2, 'N': 1})
# Position 2929: Counter({'A': 2, 'N': 1})
# Position 2930: Counter({'G': 2, 'N': 1})
# Position 2931: Counter({'G': 2, 'N': 1})
# Position 2932: Counter({'A': 2, 'N': 1})
# Position 2933: Counter({'C': 2, 'N': 1})
# Position 2934: Counter({'A': 2, 'N': 1})
# Position 2935: Counter({'A': 2, 'N': 1})
# Position 2936: Counter({'C': 2, 'N': 1})
# Position 2937: Counter({'A': 2, 'N': 1})
# Position 2938: Counter({'C': 2, 'N': 1})
# Position 2939: Counter({'T': 2, 'N': 1})
# Position 2940: Counter({'G': 2, 'N': 1})
# Position 2941: Counter({'G': 2, 'N': 1})
# Position 2942: Counter({'G': 2, 'N': 1})
# Position 2943: Counter({'G': 2, 'N': 1})
# Position 2944: Counter({'A': 2, 'N': 1})
# Position 2945: Counter({'G': 2, 'N': 1})
# Position 2946: Counter({'G': 2, 'N': 1})
# Position 2947: Counter({'T': 2, 'N': 1})
# Position 2948: Counter({'G': 2, 'N': 1})
# Position 2949: Counter({'G': 2, 'N': 1})
# Position 2950: Counter({'T': 2, 'N': 1})
# Position 2951: Counter({'C': 2, 'N': 1})
# Position 2952: Counter({'G': 2, 'N': 1})
# Position 2953: Counter({'C': 2, 'N': 1})
# Position 2954: Counter({'T': 2, 'N': 1})
# Position 2955: Counter({'G': 2, 'N': 1})
# Position 2956: Counter({'T': 2, 'N': 1})
# Position 2957: Counter({'A': 2, 'N': 1})
# Position 2958: Counter({'A': 2, 'N': 1})
# Position 2959: Counter({'A': 2, 'N': 1})
# Position 2960: Counter({'A': 2, 'N': 1})
# Position 2961: Counter({'A': 2, 'N': 1})
# Position 2962: Counter({'A': 2, 'N': 1})
# Position 2963: Counter({'G': 2, 'N': 1})
# Position 2964: Counter({'C': 2, 'N': 1})
# Position 2965: Counter({'T': 2, 'N': 1})
# Position 2966: Counter({'T': 2, 'N': 1})
# Position 2967: Counter({'C': 2, 'N': 1})
# Position 2968: Counter({'A': 2, 'N': 1})
# Position 2969: Counter({'G': 2, 'N': 1})
# Position 2970: Counter({'C': 2, 'N': 1})
# Position 2971: Counter({'A': 2, 'N': 1})
# Position 2972: Counter({'T': 2, 'N': 1})
# Position 2973: Counter({'A': 2, 'N': 1})
# Position 2974: Counter({'G': 2, 'N': 1})
# Position 2975: Counter({'T': 2, 'N': 1})
# Position 2976: Counter({'A': 2, 'N': 1})
# Position 2977: Counter({'C': 2, 'N': 1})
# Position 2978: Counter({'T': 2, 'N': 1})
# Position 2979: Counter({'G': 2, 'N': 1})
# Position 2980: Counter({'A': 2, 'N': 1})
# Position 2981: Counter({'A': 2, 'N': 1})
# Position 2982: Counter({'G': 2, 'N': 1})
# Position 2983: Counter({'A': 2, 'N': 1})
# Position 2984: Counter({'G': 2, 'N': 1})
# Position 2985: Counter({'C': 2, 'N': 1})
# Position 2986: Counter({'A': 2, 'N': 1})
# Position 2987: Counter({'C': 2, 'N': 1})
# Position 2988: Counter({'C': 2, 'N': 1})
# Position 2989: Counter({'T': 2, 'N': 1})
# Position 2990: Counter({'A': 2, 'N': 1})
# Position 2991: Counter({'A': 2, 'N': 1})
# Position 2992: Counter({'G': 2, 'N': 1})
# Position 2993: Counter({'A': 2, 'N': 1})
# Position 2994: Counter({'G': 2, 'N': 1})
# Position 2995: Counter({'A': 2, 'N': 1})
# Position 2996: Counter({'C': 2, 'N': 1})
# Position 2997: Counter({'T': 2, 'N': 1})
# Position 2998: Counter({'T': 2, 'N': 1})
# Position 2999: Counter({'T': 2, 'N': 1})
# Position 3000: Counter({'G': 2, 'N': 1})
# Position 3001: Counter({'A': 2, 'N': 1})
# Position 3002: Counter({'A': 2, 'N': 1})
# Position 3003: Counter({'A': 2, 'N': 1})
# Position 3004: Counter({'G': 2, 'N': 1})
# Position 3005: Counter({'G': 2, 'N': 1})
# Position 3006: Counter({'G': 2, 'N': 1})
# Position 3007: Counter({'A': 2, 'N': 1})
# Position 3008: Counter({'A': 2, 'N': 1})
# Position 3009: Counter({'A': 2, 'N': 1})
# Position 3010: Counter({'T': 2, 'N': 1})
# Position 3011: Counter({'T': 2, 'N': 1})
# Position 3012: Counter({'G': 2, 'N': 1})
# Position 3013: Counter({'A': 2, 'N': 1})
# Position 3014: Counter({'A': 2, 'N': 1})
# Position 3015: Counter({'A': 2, 'N': 1})
# Position 3016: Counter({'T': 2, 'N': 1})
# Position 3017: Counter({'C': 2, 'N': 1})
# Position 3018: Counter({'C': 2, 'N': 1})
# Position 3019: Counter({'T': 2, 'N': 1})
# Position 3020: Counter({'G': 2, 'N': 1})
# Position 3021: Counter({'A': 2, 'N': 1})
# Position 3022: Counter({'A': 2, 'N': 1})
# Position 3023: Counter({'A': 2, 'N': 1})
# Position 3024: Counter({'T': 2, 'N': 1})
# Position 3025: Counter({'C': 2, 'N': 1})
# Position 3026: Counter({'C': 2, 'N': 1})
# Position 3027: Counter({'C': 2, 'N': 1})
# Position 3028: Counter({'T': 2, 'N': 1})
# Position 3029: Counter({'A': 2, 'N': 1})
# Position 3030: Counter({'C': 2, 'N': 1})
# Position 3031: Counter({'A': 2, 'N': 1})
# Position 3032: Counter({'G': 2, 'N': 1})
# Position 3033: Counter({'C': 2, 'N': 1})
# Position 3034: Counter({'A': 2, 'N': 1})
# Position 3035: Counter({'T': 2, 'N': 1})
# Position 3036: Counter({'G': 2, 'N': 1})
# Position 3037: Counter({'A': 2, 'N': 1})
# Position 3038: Counter({'C': 2, 'N': 1})
# Position 3039: Counter({'A': 2, 'N': 1})
# Position 3040: Counter({'A': 2, 'N': 1})
# ...
# Position 6482: Counter({'T': 2, 'N': 1})
# Position 6483: Counter({'A': 2, 'N': 1})
# Position 6484: Counter({'A': 2, 'N': 1})
# Position 6485: Counter({'A': 2, 'N': 1})
# Position 6486: Counter({'T': 2, 'N': 1})
# Position 6487: Counter({'A': 2, 'N': 1})
# Position 6488: Counter({'G': 2, 'N': 1})
# Position 6489: Counter({'T': 2, 'N': 1})
# Position 6490: Counter({'A': 2, 'N': 1})
# Position 6491: Counter({'A': 2, 'N': 1})
# Position 6492: Counter({'C': 2, 'N': 1})
# Position 6493: Counter({'A': 2, 'N': 1})
# Position 6494: Counter({'G': 2, 'N': 1})
# Position 6495: Counter({'T': 2, 'N': 1})
# Position 6496: Counter({'A': 2, 'N': 1})
# Position 6497: Counter({'A': 2, 'N': 1})
# Position 6498: Counter({'G': 2, 'N': 1})
# Position 6499: Counter({'T': 2, 'N': 1})
# Position 6500: Counter({'C': 2, 'N': 1})
# Position 6501: Counter({'A': 2, 'N': 1})
# Position 6502: Counter({'G': 2, 'N': 1})
# Position 6503: Counter({'C': 2, 'N': 1})
# Position 6504: Counter({'A': 2, 'N': 1})
# Position 6505: Counter({'G': 2, 'N': 1})
# Position 6506: Counter({'G': 2, 'N': 1})
# Position 6507: Counter({'A': 2, 'N': 1})
# Position 6508: Counter({'T': 2, 'N': 1})
# Position 6509: Counter({'T': 2, 'N': 1})
# Position 6510: Counter({'A': 2, 'N': 1})
# Position 6511: Counter({'T': 2, 'N': 1})
# Position 6512: Counter({'C': 2, 'N': 1})
# Position 6513: Counter({'C': 2, 'N': 1})
# Position 6514: Counter({'A': 2, 'N': 1})
# Position 6515: Counter({'A': 2, 'N': 1})
# Position 6516: Counter({'A': 2, 'N': 1})
# Position 6517: Counter({'C': 2, 'N': 1})
# Position 6518: Counter({'A': 2, 'N': 1})
# Position 6519: Counter({'A': 2, 'N': 1})
# Position 6520: Counter({'A': 2, 'N': 1})
# Position 6521: Counter({'A': 2, 'N': 1})
# Position 6522: Counter({'G': 2, 'N': 1})
# Position 6523: Counter({'A': 2, 'N': 1})
# Position 6524: Counter({'C': 2, 'N': 1})
# Position 6525: Counter({'T': 2, 'N': 1})
# Position 6526: Counter({'A': 2, 'N': 1})
# Position 6527: Counter({'G': 2, 'N': 1})
# Position 6528: Counter({'G': 2, 'N': 1})
# Position 6529: Counter({'T': 2, 'N': 1})
# Position 6530: Counter({'T': 2, 'N': 1})
# Position 6531: Counter({'T': 2, 'N': 1})
# Position 6532: Counter({'T': 2, 'N': 1})
# Position 6533: Counter({'A': 2, 'N': 1})
# Position 6534: Counter({'T': 2, 'N': 1})
# Position 6535: Counter({'G': 2, 'N': 1})
# Position 6536: Counter({'A': 2, 'N': 1})
# Position 6537: Counter({'G': 2, 'N': 1})
# Position 6538: Counter({'A': 2, 'N': 1})
# Position 6539: Counter({'T': 2, 'N': 1})
# Position 6540: Counter({'A': 2, 'N': 1})
# Position 6541: Counter({'A': 2, 'N': 1})
# Position 6542: Counter({'G': 2, 'N': 1})
# Position 6543: Counter({'C': 2, 'N': 1})
# Position 6544: Counter({'T': 2, 'N': 1})
# Position 6545: Counter({'T': 2, 'N': 1})
# Position 6546: Counter({'G': 2, 'N': 1})
# Position 6547: Counter({'A': 2, 'N': 1})
# Position 6548: Counter({'T': 2, 'N': 1})
# Position 6549: Counter({'T': 2, 'N': 1})
# Position 6550: Counter({'T': 2, 'N': 1})
# Position 6551: Counter({'A': 2, 'N': 1})
# Position 6552: Counter({'A': 2, 'N': 1})
# Position 6553: Counter({'G': 2, 'N': 1})
# Position 6554: Counter({'A': 2, 'N': 1})
# Position 6555: Counter({'A': 2, 'N': 1})
# Position 6556: Counter({'A': 2, 'N': 1})
# Position 6557: Counter({'A': 2, 'N': 1})
# Position 6558: Counter({'A': 2, 'N': 1})
# Position 6559: Counter({'A': 2, 'N': 1})
# Position 6560: Counter({'A': 2, 'N': 1})
# Position 6561: Counter({'C': 2, 'N': 1})
# Position 6562: Counter({'A': 2, 'N': 1})
# Position 6563: Counter({'A': 2, 'N': 1})
# Position 6564: Counter({'T': 2, 'N': 1})
# Position 6565: Counter({'T': 2, 'N': 1})
# Position 6566: Counter({'A': 2, 'N': 1})
# Position 6567: Counter({'A': 2, 'N': 1})
# Position 6568: Counter({'A': 2, 'N': 1})
# Position 6569: Counter({'G': 2, 'N': 1})
# Position 6570: Counter({'T': 2, 'N': 1})
# Position 6571: Counter({'A': 2, 'N': 1})
# Position 6572: Counter({'T': 2, 'N': 1})
# Position 6573: Counter({'G': 2, 'N': 1})
# Position 6574: Counter({'A': 2, 'N': 1})
# Position 6575: Counter({'A': 2, 'N': 1})
# Position 6576: Counter({'T': 2, 'N': 1})
# Position 6577: Counter({'A': 2, 'N': 1})
# Position 6578: Counter({'T': 2, 'N': 1})
# Position 6579: Counter({'C': 2, 'N': 1})
# Position 6580: Counter({'A': 2, 'N': 1})
# Position 6581: Counter({'G': 2, 'N': 1})
# Position 6582: Counter({'A': 2, 'N': 1})
# Position 6583: Counter({'A': 2, 'N': 1})
# Position 6584: Counter({'A': 2, 'N': 1})
# Position 6585: Counter({'T': 2, 'N': 1})
# Position 6586: Counter({'A': 2, 'N': 1})
# Position 6587: Counter({'C': 2, 'N': 1})
# Position 6588: Counter({'T': 2, 'N': 1})
# Position 6589: Counter({'G': 2, 'N': 1})
# Position 6590: Counter({'T': 2, 'N': 1})
# Position 6591: Counter({'G': 2, 'N': 1})
# Position 6592: Counter({'T': 2, 'N': 1})
# Position 6593: Counter({'G': 2, 'N': 1})
# Position 6594: Counter({'T': 2, 'N': 1})
# Position 6595: Counter({'T': 2, 'N': 1})
# Position 6596: Counter({'T': 2, 'N': 1})
# Position 6597: Counter({'A': 2, 'N': 1})
# Position 6598: Counter({'C': 2, 'N': 1})
# Position 6599: Counter({'T': 2, 'N': 1})
# Position 6600: Counter({'C': 2, 'N': 1})
# Position 6601: Counter({'T': 2, 'N': 1})
# Position 6602: Counter({'C': 2, 'N': 1})
# Position 6603: Counter({'A': 2, 'N': 1})
# Position 6604: Counter({'G': 2, 'N': 1})
# Position 6605: Counter({'A': 2, 'N': 1})
# Position 6606: Counter({'T': 2, 'N': 1})
# Position 6607: Counter({'T': 2, 'N': 1})
# Position 6608: Counter({'T': 2, 'N': 1})
# Position 6609: Counter({'T': 2, 'N': 1})
# Position 6610: Counter({'A': 2, 'N': 1})
# Position 6611: Counter({'G': 2, 'N': 1})
# Position 6612: Counter({'T': 2, 'N': 1})
# Position 6613: Counter({'T': 2, 'N': 1})
# Position 6614: Counter({'G': 2, 'N': 1})
# Position 6615: Counter({'G': 2, 'N': 1})
# Position 6616: Counter({'T': 2, 'N': 1})
# Position 6617: Counter({'T': 2, 'N': 1})
# Position 6618: Counter({'G': 2, 'N': 1})
# Position 6619: Counter({'G': 2, 'N': 1})
# Position 6620: Counter({'A': 2, 'N': 1})
# Position 6621: Counter({'T': 2, 'N': 1})
# Position 6622: Counter({'T': 2, 'N': 1})
# Position 6623: Counter({'T': 2, 'N': 1})
# Position 6624: Counter({'A': 2, 'N': 1})
# Position 6625: Counter({'A': 2, 'N': 1})
# Position 6626: Counter({'T': 2, 'N': 1})
# Position 6627: Counter({'A': 2, 'N': 1})
# Position 6628: Counter({'T': 2, 'N': 1})
# Position 6629: Counter({'C': 2, 'N': 1})
# Position 6630: Counter({'A': 2, 'N': 1})
# Position 6631: Counter({'A': 2, 'N': 1})
# Position 6632: Counter({'G': 2, 'N': 1})
# Position 6633: Counter({'A': 2, 'N': 1})
# Position 6634: Counter({'T': 2, 'N': 1})
# Position 6635: Counter({'A': 2, 'N': 1})
# Position 6636: Counter({'A': 2, 'N': 1})
# Position 6637: Counter({'C': 2, 'N': 1})
# Position 6638: Counter({'T': 2, 'N': 1})
# Position 6639: Counter({'A': 2, 'N': 1})
# Position 6640: Counter({'G': 2, 'N': 1})
# Position 6641: Counter({'C': 2, 'N': 1})
# Position 6642: Counter({'T': 2, 'N': 1})
# Position 6643: Counter({'G': 2, 'N': 1})
# Position 6644: Counter({'C': 2, 'N': 1})
# Position 6645: Counter({'T': 2, 'N': 1})
# Position 6646: Counter({'A': 2, 'N': 1})
# Position 6647: Counter({'A': 2, 'N': 1})
# Position 6648: Counter({'G': 2, 'N': 1})
# Position 6649: Counter({'C': 2, 'N': 1})
# Position 6650: Counter({'G': 2, 'N': 1})
# Position 6651: Counter({'T': 2, 'N': 1})
# Position 6652: Counter({'T': 2, 'N': 1})
# Position 6653: Counter({'T': 2, 'N': 1})
# Position 6654: Counter({'C': 2, 'N': 1})
# Position 6655: Counter({'A': 2, 'N': 1})
# Position 6656: Counter({'T': 2, 'N': 1})
# Position 6657: Counter({'A': 2, 'N': 1})
# Position 6658: Counter({'A': 2, 'N': 1})
# Position 6659: Counter({'T': 2, 'N': 1})
# Position 6660: Counter({'T': 2, 'N': 1})
# Position 6661: Counter({'C': 2, 'N': 1})
# Position 6662: Counter({'T': 2, 'N': 1})
# Position 6663: Counter({'C': 2, 'N': 1})
# Position 6664: Counter({'A': 2, 'N': 1})
# Position 6665: Counter({'C': 2, 'N': 1})
# Position 6666: Counter({'A': 2, 'N': 1})
# Position 6667: Counter({'G': 2, 'N': 1})
# Position 6668: Counter({'T': 2, 'N': 1})
# Position 6669: Counter({'G': 2, 'N': 1})
# Position 6670: Counter({'A': 2, 'N': 1})
# Position 6671: Counter({'T': 2, 'N': 1})
# Position 6672: Counter({'A': 2, 'N': 1})
# Position 6673: Counter({'T': 2, 'N': 1})
# Position 6674: Counter({'T': 2, 'N': 1})
# Position 6675: Counter({'A': 2, 'N': 1})
# Position 6676: Counter({'G': 2, 'N': 1})
# Position 6677: Counter({'A': 2, 'N': 1})
# Position 6678: Counter({'T': 2, 'N': 1})
# Position 6679: Counter({'T': 2, 'N': 1})
# Position 6680: Counter({'T': 2, 'N': 1})
# Position 6681: Counter({'C': 2, 'N': 1})
# Position 6682: Counter({'A': 2, 'N': 1})
# Position 6683: Counter({'A': 2, 'N': 1})
# Position 6684: Counter({'A': 2, 'N': 1})
# Position 6685: Counter({'A': 2, 'N': 1})
# Position 6686: Counter({'T': 2, 'N': 1})
# Position 6687: Counter({'G': 2, 'N': 1})
# Position 6688: Counter({'A': 2, 'N': 1})
# Position 6689: Counter({'C': 2, 'N': 1})
# Position 6690: Counter({'A': 2, 'N': 1})
# Position 6691: Counter({'C': 2, 'N': 1})
# Position 6692: Counter({'T': 2, 'N': 1})
# Position 6693: Counter({'G': 2, 'N': 1})
# Position 6694: Counter({'A': 2, 'N': 1})
# Position 6695: Counter({'G': 2, 'N': 1})
# Position 6696: Counter({'A': 2, 'N': 1})
# Position 6697: Counter({'G': 2, 'N': 1})
# Position 6698: Counter({'A': 2, 'N': 1})
# Position 6699: Counter({'A': 2, 'N': 1})
# Position 6700: Counter({'C': 2, 'N': 1})
# Position 6701: Counter({'T': 2, 'N': 1})
# Position 6702: Counter({'G': 2, 'N': 1})
# Position 6703: Counter({'A': 2, 'N': 1})
# Position 6704: Counter({'A': 2, 'N': 1})
# Position 6705: Counter({'A': 2, 'N': 1})
# Position 6706: Counter({'A': 2, 'N': 1})
# Position 6707: Counter({'A': 2, 'N': 1})
# Position 6708: Counter({'C': 2, 'N': 1})
# Position 6709: Counter({'T': 2, 'N': 1})
# Position 6710: Counter({'A': 2, 'N': 1})
# Position 6711: Counter({'C': 2, 'N': 1})
# Position 6712: Counter({'A': 2, 'N': 1})
# Position 6713: Counter({'T': 2, 'N': 1})
# Position 6714: Counter({'C': 2, 'N': 1})
# Position 6715: Counter({'A': 2, 'N': 1})
# Position 6716: Counter({'G': 2, 'N': 1})
# Position 6717: Counter({'T': 2, 'N': 1})
# Position 6718: Counter({'C': 2, 'N': 1})
# Position 6719: Counter({'A': 2, 'N': 1})
# Position 6720: Counter({'A': 2, 'N': 1})
# Position 6721: Counter({'A': 2, 'N': 1})
# Position 6722: Counter({'T': 2, 'N': 1})
# Position 6723: Counter({'T': 2, 'N': 1})
# Position 6724: Counter({'C': 2, 'N': 1})
# Position 6725: Counter({'A': 2, 'N': 1})
# Position 6726: Counter({'T': 2, 'N': 1})
# Position 6727: Counter({'G': 2, 'N': 1})
# Position 6728: Counter({'T': 2, 'N': 1})
# Position 6729: Counter({'A': 2, 'N': 1})
# Position 6730: Counter({'T': 2, 'N': 1})
# Position 6731: Counter({'G': 2, 'N': 1})
# Position 6732: Counter({'T': 2, 'N': 1})
# Position 6733: Counter({'A': 2, 'N': 1})
# Position 6734: Counter({'T': 2, 'N': 1})
# Position 6735: Counter({'A': 2, 'N': 1})
# Position 6736: Counter({'T': 2, 'N': 1})
# Position 6737: Counter({'C': 2, 'N': 1})
# Position 6738: Counter({'A': 2, 'N': 1})
# Position 6739: Counter({'T': 2, 'N': 1})
# Position 6740: Counter({'A': 2, 'N': 1})
# Position 6741: Counter({'T': 2, 'N': 1})
# Position 6742: Counter({'A': 2, 'N': 1})
# Position 6743: Counter({'G': 2, 'N': 1})
# Position 6744: Counter({'C': 2, 'N': 1})
# Position 6745: Counter({'C': 2, 'N': 1})
# Position 6746: Counter({'T': 2, 'N': 1})
# Position 6747: Counter({'T': 2, 'N': 1})
# Position 6748: Counter({'T': 2, 'N': 1})
# Position 6749: Counter({'A': 2, 'N': 1})
# Position 6750: Counter({'A': 2, 'N': 1})
# Position 6751: Counter({'C': 2, 'N': 1})
# Position 6752: Counter({'T': 2, 'N': 1})
# Position 6753: Counter({'T': 2, 'N': 1})
# Position 6754: Counter({'T': 2, 'N': 1})
# Position 6755: Counter({'T': 2, 'N': 1})
# Position 6756: Counter({'T': 2, 'N': 1})
# Position 6757: Counter({'A': 2, 'N': 1})
# Position 6758: Counter({'C': 2, 'N': 1})
# Position 6759: Counter({'A': 2, 'N': 1})
# Position 6760: Counter({'T': 2, 'N': 1})
# Position 6761: Counter({'T': 2, 'N': 1})
# Position 6762: Counter({'A': 2, 'N': 1})
# Position 6763: Counter({'A': 2, 'N': 1})
# Position 6764: Counter({'T': 2, 'N': 1})
# Position 6765: Counter({'C': 2, 'N': 1})
# Position 6766: Counter({'A': 2, 'N': 1})
# Position 6767: Counter({'G': 2, 'N': 1})
# Position 6768: Counter({'A': 2, 'N': 1})
# Position 6769: Counter({'T': 2, 'N': 1})
# Position 6770: Counter({'T': 2, 'N': 1})
# Position 6771: Counter({'C': 2, 'N': 1})
# Position 6772: Counter({'T': 2, 'N': 1})
# Position 6773: Counter({'T': 2, 'N': 1})
# Position 6774: Counter({'A': 2, 'N': 1})
# Position 6775: Counter({'G': 2, 'N': 1})
# Position 6776: Counter({'T': 2, 'N': 1})
# Position 6777: Counter({'A': 2, 'N': 1})
# Position 6778: Counter({'A': 2, 'N': 1})
# Position 6779: Counter({'A': 2, 'N': 1})
# Position 6780: Counter({'A': 2, 'N': 1})
# Position 6781: Counter({'T': 2, 'N': 1})
# Position 6782: Counter({'G': 2, 'N': 1})
# Position 6783: Counter({'C': 2, 'N': 1})
# Position 6784: Counter({'A': 2, 'N': 1})
# Position 6785: Counter({'G': 2, 'N': 1})
# Position 6786: Counter({'A': 2, 'N': 1})
# Position 6787: Counter({'C': 2, 'N': 1})
# Position 6788: Counter({'T': 2, 'N': 1})
# Position 6789: Counter({'G': 2, 'N': 1})
# Position 6790: Counter({'T': 2, 'N': 1})
# Position 6791: Counter({'A': 2, 'N': 1})
# Position 6792: Counter({'T': 2, 'N': 1})
# Position 6793: Counter({'A': 2, 'N': 1})
# Position 6794: Counter({'C': 2, 'N': 1})
# Position 6795: Counter({'C': 2, 'N': 1})
# Position 6796: Counter({'T': 2, 'N': 1})
# Position 6797: Counter({'A': 2, 'N': 1})
# Position 6798: Counter({'A': 2, 'N': 1})
# Position 6799: Counter({'A': 2, 'N': 1})
# Position 6800: Counter({'T': 2, 'N': 1})
# Position 6801: Counter({'A': 2, 'N': 1})
# Position 6802: Counter({'T': 2, 'N': 1})
# Position 6803: Counter({'T': 2, 'N': 1})
# Position 6804: Counter({'A': 2, 'N': 1})
# Position 6805: Counter({'A': 2, 'N': 1})
# Position 6806: Counter({'A': 2, 'N': 1})
# Position 6807: Counter({'A': 2, 'N': 1})
# Position 6808: Counter({'T': 2, 'N': 1})
# Position 6809: Counter({'A': 2, 'N': 1})
# Position 6810: Counter({'T': 2, 'N': 1})
# Position 6811: Counter({'T': 2, 'N': 1})
# Position 6812: Counter({'T': 2, 'N': 1})
# Position 6813: Counter({'A': 2, 'N': 1})
# Position 6814: Counter({'C': 2, 'N': 1})
# Position 6815: Counter({'T': 2, 'N': 1})
# Position 6816: Counter({'T': 2, 'N': 1})
# Position 6817: Counter({'T': 2, 'N': 1})
# Position 6818: Counter({'T': 2, 'N': 1})
# Position 6819: Counter({'A': 2, 'N': 1})
# Position 6820: Counter({'T': 2, 'N': 1})
# Position 6821: Counter({'A': 2, 'N': 1})
# Position 6822: Counter({'A': 2, 'N': 1})
# Position 6823: Counter({'T': 2, 'N': 1})
# Position 6824: Counter({'C': 2, 'N': 1})
# Position 6825: Counter({'T': 2, 'N': 1})
# Position 6826: Counter({'T': 2, 'N': 1})
# Position 6827: Counter({'A': 2, 'N': 1})
# Position 6828: Counter({'C': 2, 'N': 1})
# Position 6829: Counter({'C': 2, 'N': 1})
# Position 6830: Counter({'T': 2, 'N': 1})
# Position 6831: Counter({'T': 2, 'N': 1})
# Position 6832: Counter({'T': 2, 'N': 1})
# Position 6833: Counter({'T': 2, 'N': 1})
# Position 6834: Counter({'A': 2, 'N': 1})
# Position 6835: Counter({'T': 2, 'N': 1})
# Position 6836: Counter({'T': 2, 'N': 1})
# Position 6837: Counter({'T': 2, 'N': 1})
# Position 6838: Counter({'C': 2, 'N': 1})
# Position 6839: Counter({'A': 2, 'N': 1})
# Position 6840: Counter({'A': 2, 'N': 1})
# Position 6841: Counter({'T': 2, 'N': 1})
# Position 6842: Counter({'A': 2, 'N': 1})
# Position 6843: Counter({'T': 2, 'N': 1})
# Position 6844: Counter({'A': 2, 'N': 1})
# Position 6845: Counter({'A': 2, 'N': 1})
# Position 6846: Counter({'A': 2, 'N': 1})
# Position 6847: Counter({'T': 2, 'N': 1})
# Position 6848: Counter({'A': 2, 'N': 1})
# Position 6849: Counter({'A': 2, 'N': 1})
# Position 6850: Counter({'A': 2, 'N': 1})
# Position 6851: Counter({'A': 2, 'N': 1})
# Position 6852: Counter({'T': 2, 'N': 1})
# Position 6853: Counter({'T': 2, 'N': 1})
# Position 6854: Counter({'C': 2, 'N': 1})
# Position 6855: Counter({'T': 2, 'N': 1})
# Position 6856: Counter({'T': 2, 'N': 1})
# Position 6857: Counter({'C': 2, 'N': 1})
# Position 6858: Counter({'T': 2, 'N': 1})
# Position 6859: Counter({'T': 2, 'N': 1})
# Position 6860: Counter({'A': 2, 'N': 1})
# Position 6861: Counter({'G': 2, 'N': 1})
# Position 6862: Counter({'G': 2, 'N': 1})
# Position 6863: Counter({'T': 2, 'N': 1})
# Position 6864: Counter({'T': 2, 'N': 1})
# Position 6865: Counter({'A': 2, 'N': 1})
# Position 6866: Counter({'A': 2, 'N': 1})
# Position 6867: Counter({'A': 2, 'N': 1})
# Position 6868: Counter({'A': 2, 'N': 1})
# Position 6869: Counter({'A': 2, 'N': 1})
# Position 6870: Counter({'A': 2, 'N': 1})
# Percent Identity: 78.19%

# %%
#q2:
import networkx as nx
import matplotlib.pyplot as plt

def find_kmers(sequence, k):
    kmers = [sequence[i:i+k] for i in range(len(sequence)-k+1)]
    return kmers
def plot_de_bruijn_graph(de_bruijn_graph, output_filename):
    pos = nx.spring_layout(de_bruijn_graph)
    nx.draw(de_bruijn_graph, pos, with_labels=True)
    plt.savefig(output_filename)
    plt.show()
def assemble_sequence_from_graph(de_bruijn_graph):
    def find_eulerian_path(graph):
        start_node = next((node for node, neighbors in graph.items() if len(neighbors) % 2 != 0), next(iter(graph)))
        path, stack = [], [start_node]
        while stack:
            node = stack[-1]
            if graph[node]:
                stack.append(graph[node].pop())
            else:
                path.append(stack.pop())
        return path[::-1]

    graph = {node: list(neighbors) for node, neighbors in de_bruijn_graph.items()}
    for neighbors in de_bruijn_graph.values():
        for neighbor in neighbors:
            if neighbor not in graph:
                graph[neighbor] = []

    path = find_eulerian_path(graph)
    sequence = ''.join(node[-1] for node in path[1:])
    return path[0] + sequence

def build_de_bruijn_graph(kmers):
    graph = {}
    for kmer in kmers:
        prefix = kmer[:-1]
        suffix = kmer[1:]
        if prefix in graph:
            graph[prefix].append(suffix)
        else:
            graph[prefix] = [suffix]
    return graph

def Q2(test_case):
    sequence, k = test_case
    kmers = find_kmers(sequence, k)
    de_bruijn_graph = build_de_bruijn_graph(kmers)
    assembled_sequence = assemble_sequence_from_graph(de_bruijn_graph)
    return assembled_sequence


def menu():
    functions = [
        {"description": "Find K-mers and Assemble Sequence", "function": Q1},
        {"description": "Plot De Bruijn Graph", "function": plot_de_bruijn_graph}

    ]

    print("---------Welcome to my program-----------:")
    for i in range(len(functions)):
        print(str(i + 1) + ": " + functions[i]['description'])

    choice = int(input("Enter the number of the option you want to execute: ")) - 1
    if 0 <= choice < len(functions):
        return functions[choice]['function']
    else:
        print("Invalid choice. Exiting program.")
        return None
def build_networkx_de_bruijn_graph(de_bruijn_dict):
    G = nx.DiGraph()
    for node, neighbors in de_bruijn_dict.items():
        for neighbor in neighbors:
            G.add_edge(node, neighbor)
    return G

if __name__ == "__main__":
    function = menu()
    if function:
        test_case = ("TGTAGAAAGTACCCAGTGCTCAGTATAG", 5)
        if function == Q2:
            output = function(test_case)
            print("Assembled Sequence:", output)
        else:
            output_filename = "de_bruijn_graph.png"
            kmers = find_kmers(test_case[0], test_case[1])
            de_bruijn_dict = build_de_bruijn_graph(kmers)
            de_bruijn_graph = build_networkx_de_bruijn_graph(de_bruijn_dict)
            function(de_bruijn_graph, output_filename)
    else:
        print("Exiting program.")
# Out:
# ---------Welcome to my program-----------:
# 1: Find K-mers and Assemble Sequence
# 2: Plot De Bruijn Graph

# %%
#q3

def BWT(str_input):
  rotations=[]
  for i in range(len(str_input)):
    rotations.append(str_input[i:]+ str_input[:i])

  rotations.sort()
  bwt=""
  for rotation in rotations:
    bwt+=rotation[-1]


  return bwt

def Q3(test_case):
    transformed_input=BWT(test_case)
    return transformed_input


BWT_output=Q3("GCGTGCCTGGTCA$")
print(BWT_output)
# Out:
# ACTGGCT$TGCGGC
